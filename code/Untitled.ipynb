# %%
import pandas
target_df = pandas.read_csv('../data/model_data.csv')

# %%
target_df.head()
# Out:
#    Unnamed: 0 OWNER_CL_ID  ZIP_CD  GAS_RETAIL_CARD_USAGE_CD  \
# 0           1    10004700   89011                         0
# 1           2    10005cd7   92307                         0
# 2           3    1000a8f6   78550                         0
# 3           4    1000b62a   91789                         0
# 4           5    1000cbcd   78635                         0
#
#    MASTERCARD_USAGE_CD  VISA_CREDIT_CARD_USAGE_CD  \
# 0                    1                          1
# 1                    0                          0
# 2                    1                          0
# 3                    0                          0
# 4                    0                          0
#
#    COMMUNITY_CAUSES_CHARITY_CD  DOMESTIC_BUSINESS_TRAVEL_CD  \
# 0                 1.000000e+12                            0
# 1                 0.000000e+00                            0
# 2                 1.001010e+12                            0
# ...

# %%
len(target_df)
# Out:
# 250374

# %%
import numpy as np

target_df["total_premium"] = target_df['avg_prem'] * target_df['num_policies']

# %%
target_df.head()
# Out:
#    Unnamed: 0 OWNER_CL_ID  ZIP_CD  GAS_RETAIL_CARD_USAGE_CD  \
# 0           1    10004700   89011                         0
# 1           2    10005cd7   92307                         0
# 2           3    1000a8f6   78550                         0
# 3           4    1000b62a   91789                         0
# 4           5    1000cbcd   78635                         0
#
#    MASTERCARD_USAGE_CD  VISA_CREDIT_CARD_USAGE_CD  \
# 0                    1                          1
# 1                    0                          0
# 2                    1                          0
# 3                    0                          0
# 4                    0                          0
#
#    COMMUNITY_CAUSES_CHARITY_CD  DOMESTIC_BUSINESS_TRAVEL_CD  \
# 0                 1.000000e+12                            0
# 1                 0.000000e+00                            0
# 2                 1.001010e+12                            0
# ...

# %%
target_df.to_csv('../output/target_predictions.csv')

# %%
target_df.describe()
# Out:
#           Unnamed: 0         ZIP_CD  GAS_RETAIL_CARD_USAGE_CD  \
# count  250374.000000  250374.000000             250374.000000
# mean   125187.500000   46302.981803                  0.322406
# std     72276.892486   33617.708289                  1.595716
# min         1.000000    1001.000000                  0.000000
# 25%     62594.250000   11550.000000                  0.000000
# 50%    125187.500000   35756.000000                  0.000000
# 75%    187780.750000   78660.000000                  0.000000
# max    250374.000000   99929.000000                 11.000000
#
#        MASTERCARD_USAGE_CD  VISA_CREDIT_CARD_USAGE_CD  \
# count        250374.000000              250374.000000
# mean              0.455059                   0.537077
# std               1.929879                   1.955580
# min               0.000000                   0.000000
# 25%               0.000000                   0.000000
# 50%               0.000000                   0.000000
# ...
